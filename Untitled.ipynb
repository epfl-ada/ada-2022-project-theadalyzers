# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(1,2, figsize=(12,8), sharey=True)

vis_f=pd.read_csv('.vis_f.csv', index_col=0)
vis_u=pd.read_csv('.vis_u.csv', index_col=0)
vis=pd.concat([vis_f,vis_u], axis=0)

sns.barplot(y='#_clicks / #_hyperlinks', x=vis.index, data=vis, palette=sns.color_palette("Set2"), hue='is_successful', edgecolor='k', ax=ax[0])

ax[0].set_title('Distribution of clickability preference', fontsize=18)
ax[0].set_xlabel('Positioning', fontsize=18)
ax[0].set_ylabel('#_clicks / #_hyperlinks', fontsize=18)
ax[0].legend_.set_title('')
labels = ['Unsuccessful', 'Successful']
for t, l in zip(ax.legend_.texts, labels):
    t.set_text(l)



vis=pd.read_csv('.vis_img.csv')

sns.barplot(y='#_clicks / #_links_img', x=vis_img.index, data=vis_img, palette=sns.color_palette("Set2"), hue='is_successful', edgecolor='k', ax=ax[1])

ax[1].set_title('Distribution of clickability preference', fontsize=18)
ax[1].set_xlabel('Positioning', fontsize=18)
ax[1].set_ylabel('#_clicks / #_hyperlinks', fontsize=18)
ax[1].legend_.set_title('')
labels = ['Unsuccessful', 'Successful']
for t, l in zip(ax.legend_.texts, labels):
    t.set_text(l)

#plt.savefig('Distribution_pos_img.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 fig, ax = plt.subplots(1,2, figsize=(12,8), sharey=True)
# ----> 3 vis_f=pd.read_csv('.vis_f.csv', index_col=0)
#       4 vis_u=pd.read_csv('.vis_u.csv', index_col=0)
#       5 vis=pd.concat([vis_f,vis_u], axis=0)
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
